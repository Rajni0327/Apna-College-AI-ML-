# %%
import numpy as np
import time

# %%
#execution performance 
size = 100_00_000

#time 

py_list = list(range(size))
start = time.time()
sq_list = [x**2 for x in py_list]
end = time.time()
print(f"python list time = {end-start} seconds")


#numpy arrays
np_arr = np.array(py_list)
start = time.time()
sq_array = np_arr ** 2
end = time.time()
print(f"numpy array time = {end-start} seconds")
# Out:
# python list time = 2.744065523147583 seconds
# numpy array time = 0.07089805603027344 seconds
