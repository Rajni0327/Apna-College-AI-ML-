# %%
import numpy as np
import time

# %%
#execution performance 
size = 100_00_000

#time 

py_list = list(range(size))
start = time.time()
sq_list = [x**2 for x in py_list]
end = time.time()
print(f"python list time = {end-start} seconds")


#numpy arrays
np_arr = np.array(py_list)
start = time.time()
sq_array = np_arr ** 2
end = time.time()
print(f"numpy array time = {end-start} seconds")
# Out:
# python list time = 2.583771228790283 seconds
# numpy array time = 0.06213998794555664 seconds

# %%
#memory

import sys
print (f"python list size = {sys.getsizeof(py_list) * len(py_list)} bytes")

print (f"python list size = {np_arr.nbytes} bytes")
# Out:
# python list size = 800000560000000 bytes
# python list size = 80000000 bytes

# %%
# create -from lists 

arr = np.array([1, 2, 3, 4, 5])
print(arr, type(arr), arr.type(), arr.shape)

arr2 = np.array([1, 2, 3, 4, 5, "prime"])
print(arr2, type(arr2), arr2.arr2.shape)
# Out:
# [1 2 3 4 5] <class 'numpy.ndarray'> (5,)
# ['1' '2' '3' '4' '5' 'prime'] <class 'numpy.ndarray'> (6,)
